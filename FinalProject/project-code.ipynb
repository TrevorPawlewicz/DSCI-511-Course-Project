# %% [markdown]
# # Group 8 Final Project

# %% [markdown]
# In this file, we will go through all the steps required to replicate our data set: words counts for different genres of popular music. To do this, simply step through the entire jupyter notebook and the resulting file "word_count_by_genre.json" should resemble our dataset.
#
# NOTE: We are collecting data on the top songs in the last 7 days. Our dataset was created in December 2022 so any future replication will likely vary based on what the top songs are at that time.

# %% [markdown]
# ### Setup Imports and API Authentication

# %%
import requests
import pprint as pp

# Sign Up to get API key: https://developer.musixmatch.com/signup
api_key = "<provide your API key>"

# %% [markdown]
# ### Retrieve Song List

# %%
# API Call to get list of songs with Artist Name and Song Name
api_base_url = "https://api.musixmatch.com/ws/1.1/"

def get_songs(chart_name='top', num_songs='10', country='US'):
    track_list = []
    # Maximum page size is 100 so if we want more than 100 sounds we need to calculate the number of pages we need to retrieve
    page_nums = (num_songs // 100) + 1
    for page_num in range(1,page_nums+1):
        if num_songs <= 0:
            break
        page_size = num_songs if num_songs < 100 else 100
        # API reference: https://developer.musixmatch.com/documentation/api-reference/track-chart-get
        res = requests.get(api_base_url + f"chart.tracks.get?apikey={api_key}&chart_name={chart_name}&page={page_num}&page_size={page_size}&country={country}")
        track_list += res.json()['message']['body']['track_list']
        num_songs -= 100
    return track_list

# Get songs for data set
list_of_songs = get_songs('mxmweekly', 1000, 'US')

# Check the size of our track list and the first 10 artists and songs
print(len(list_of_songs))
pp.pprint([(track['track']['artist_name'],track['track']['track_name']) for track in list_of_songs][:10])
# Out:
# 1000
# [('Adam Sandler', 'The Thanksgiving Song'),
#  ('TheFatRat feat. Laura Brehm', 'Monody (feat. Laura Brehm)'),
#  ('MC L da Vinte feat. MC Gury', 'Parado No Bailão'),
#  ('Cloverton', 'A Hallelujah Christmas'),
#  ('Kristen Bell feat. Agatha Lee Monn & Katie Lopez',
#   'Do You Want to Build a Snowman?'),
#  ('Leonard Cohen', 'Hallelujah'),
#  ('Rihanna', 'California King Bed'),
#  ('Rick Astley', 'Never Gonna Give You Up'),
#  ('Taylor Swift', 'Anti-Hero'),
#  ('Chris Tomlin', 'How Great Is Our God')]

# %% [markdown]
# ### Scrap Lyric Data

# %%
from bs4 import BeautifulSoup
import re


def scrape_song_lyrics(artistname, songname):
    # Format Artist Name for URL
    artistname = str(artistname.replace('feat','and'))
    artistname = str(artistname.replace('&','and'))
    artistname = str(artistname.replace(' ','-'))
    artistname = re.sub(r'[^\w\s-]', '', artistname) 
    
    # Format Song Name for URL
    songname = str(songname.replace('...','-'))
    songname = str(songname.replace(' ','-'))
    songname = re.sub(r'[^\w\s-]', '', songname) 
    
    request_url = f'https://genius.com/{artistname}-{songname}-lyrics'
    page = requests.get(request_url)
    
    # If we fail to get the song lyrics by the URl, we skip this song
    if page.status_code == 404:
        return ""
    
    # Parse lyrics from HTML
    html = BeautifulSoup(page.text, 'html.parser')
    final_lyrics = ""
    lyrics = html.find_all("div", class_="Lyrics__Container-sc-1ynbvzw-6 YYrds")
    for lyric in lyrics:
        s = lyric.get_text(separator=" ")
        
        # Removing Genius anotations and background lyrics
        s = re.sub('\[[^\]]+\] | \([^\)]+\)', '', s)
        
        # Concatenating lyrics into one string
        final_lyrics += s + " "
    return final_lyrics

# Check Scrape Song Lyrics - Print first 50 characters of the following song
lyrics = scrape_song_lyrics("Zach Bryan", "The Good I'll Do")
pp.pprint(lyrics[:50]+"...")
# Out:
# "Well in You The good I'll do The good I'll do Oh, ..."

# %% [markdown]
# ### Collect and Merge Data

# %%
songs_with_metadata = []
for song in list_of_songs:
    
    lyrics = scrape_song_lyrics(song['track']['artist_name'], song['track']['track_name'])
    # Just to keep track of progress
    print("-", end = ' ')
    
    # Add lyrics to data
    song['track']['lyrics'] = lyrics
    songs_with_metadata.append(song)

# Print First 5 songs with artist name, song name and first 50 chars of lyrics
print("\n")
pp.pprint([(track['track']['artist_name'], track['track']['track_name'], track['track']['lyrics'][:50]+"...") for track in songs_with_metadata if track['track']['lyrics']][:5])
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# [('Adam Sandler',
#   'The Thanksgiving Song',
#   '"They wanna hear the thanksgiving song! All right....'),
#  ('Cloverton',
#   'A Hallelujah Christmas',
#   "I've heard about this baby boy Who's come to earth..."),
#  ('Leonard Cohen',
#   'Hallelujah',
#   "Now I've heard there was a secret chord That David..."),
#  ('Rihanna',
#   'California King Bed',
#   'Chest to chest Nose to nose Palm to palm We were a...'),
#  ('Rick Astley',
#   'Never Gonna Give You Up',
#   "Desert you Ooh-ooh-ooh-ooh Hurt you We're no stran...")]

# %% [markdown]
# ### Process Data

# %%
from nltk.tokenize import word_tokenize
from collections import defaultdict
import string

word_count_by_genre = defaultdict(lambda: defaultdict(lambda:0))

def get_genre(track):
    if 'primary_genres' in track and 'music_genre_list' in track['primary_genres'] and len(track['primary_genres']['music_genre_list']) > 0:
        return track['primary_genres']['music_genre_list'][0]['music_genre']['music_genre_name']
    else:
        return "Unclassified"
    
for song in songs_with_metadata:
    if not song['track']['lyrics']:
        # Skip songs we didn't get lyrics for
        continue
    
    # Tokenize lyrics and remove punctuation
    tokenized_lyrics = word_tokenize(song['track']['lyrics'])
    genre = get_genre(song['track'])
    for word in tokenized_lyrics:
        # Remove any remaining punctuation from the count
        if word in string.punctuation:
            continue
        
        word_count_by_genre[genre][word.lower()] += 1
        
# Diction where a Genre points to a list of word/count tuples sorted by the highest count
sorted_count_by_genre = {k1: sorted(v1.items(), key=lambda x:x[1], reverse=True) for k1, v1 in word_count_by_genre.items()}

# Check top 5 words in each genre
pp.pprint({genre: word_tuples[:5] for genre, word_tuples in sorted_count_by_genre.items()})
# Out:
# {'Adult Alternative': [('love', 22),
#                        ('i', 21),
#                        ('another', 20),
#                        ('my', 16),
#                        ('up', 15)],
#  'Adult Contemporary': [('you', 177),
#                         ('the', 128),
#                         ('i', 98),
#                         ('and', 76),
#                         ('a', 68)],
#  'Alternative': [('i', 611),
#                  ('you', 504),
#                  ('the', 374),
#                  ('to', 243),
#                  ('and', 237)],
#  'Alternative Folk': [('i', 26),
#                       ('you', 21),
#                       ('the', 20),
#                       ('na', 15),
#                       ("'re", 14)],
#  'Alternative Rap': [('i', 101),
#                      ('it', 91),
#                      ('you', 79),
#                      ("'s", 55),
#                      ('me', 52)],
#  'Ambient': [('like', 24), ('i', 22), ('it', 13), ('that', 12), ('you', 10)],
#  'American Trad Rock': [('i', 16),
#                         ('of', 8),
#                         ('she', 7),
#                         ('the', 7),
#                         ('to', 7)],
#  'Americana': [('i', 22), ('and', 17), ('’', 13), ('the', 12), ('god', 10)],
#  'Arena Rock': [('the', 14), ('of', 7), ('you', 7), ('and', 7), ('he', 6)],
#  'Blues': [('i', 57), ('you', 31), ('know', 30), ('the', 24), ('my', 24)],
#  'Blues-Rock': [("n't", 25), ('ai', 24), ('no', 19), ('it', 17), ('me', 16)],
#  'Bollywood': [('tum', 11), ('ho', 10), ('dil', 8), ('ke', 8), ('pal-pal', 7)],
#  'British Invasion': [('hoo', 28),
#                       ('you', 20),
#                       ('my', 17),
#                       ('yeah', 14),
#                       ('ooo', 14)],
#  'Britpop': [('the', 17), ('i', 14), ('it', 13), ('you', 8), ("'s", 7)],
#  'CCM': [('i', 103), ('you', 68), ('it', 43), ("'s", 39), ('am', 38)],
#  'Christian & Gospel': [('you', 454),
#                         ('i', 440),
#                         ('the', 182),
#                         ('is', 179),
#                         ('and', 173)],
#  'Christian Pop': [('i', 92), ('the', 66), ('you', 59), ('me', 39), ('of', 39)],
#  'Christmas': [('i', 61),
#                ('you', 50),
#                ("n't", 48),
#                ('christmas', 40),
#                ('this', 38)],
#  'Christmas: Modern': [('and', 14),
#                        ('reindeer', 12),
#                        ('you', 11),
#                        ('the', 10),
#                        ('rudolph', 8)],
#  'Classic Christian': [('oh', 49),
#                        ('rejoice', 44),
#                        ('more', 27),
#                        ('than', 27),
#                        ('i', 25)],
#  'Classical Crossover': [('i', 24),
#                          ('you', 13),
#                          ('in', 11),
#                          ('my', 10),
#                          ('the', 7)],
#  'College Rock': [('to', 9),
#                   ('the', 8),
#                   ('everybody', 6),
#                   ('wants', 6),
#                   ('rule', 6)],
#  'Comedy': [('i', 52), ('you', 38), ('the', 26), ('to', 25), ('turkey', 23)],
#  'Contemporary Country': [('you', 165),
#                           ('i', 153),
#                           ('the', 90),
#                           ('a', 86),
#                           ("n't", 70)],
#  'Contemporary Folk': [('you', 30),
#                        ('i', 26),
#                        ('the', 24),
#                        ('and', 22),
#                        ('of', 12)],
#  'Contemporary R&B': [('you', 423),
#                       ('i', 337),
#                       ('it', 140),
#                       ('the', 136),
#                       ('to', 125)],
#  'Country': [('i', 692), ('you', 537), ('the', 510), ('and', 372), ('a', 294)],
#  'Dance': [('i', 44), ("'m", 31), ('you', 29), ("n't", 29), ('do', 23)],
#  'Dirty South': [('i', 101), ('the', 73), ("n't", 73), ('do', 51), ("'m", 48)],
#  'Disco': [('you', 97), ('to', 65), ('the', 60), ("'re", 52), ('and', 51)],
#  'Doo Wop': [('me', 24), ('i', 16), ('and', 15), ('you', 14), ('’', 12)],
#  'East Coast Rap': [('the', 26), ('i', 25), ('we', 12), ('me', 12), ('to', 12)],
#  'Electronic': [('you', 440),
#                 ('i', 411),
#                 ('the', 274),
#                 ('me', 202),
#                 ('your', 150)],
#  'Electronica': [('i', 19), ('you', 13), ('crazy', 9), ("'re", 7), ('that', 6)],
#  'Farsi': [('که', 9), ('زن،', 6), ('زندگی،', 6), ('آزادی', 6), ('به', 5)],
#  'Folk': [('to', 8), ('blackbird', 7), ('the', 7), ('fly', 6), ('of', 5)],
#  'Folk-Rock': [('i', 247),
#                ('the', 203),
#                ('you', 193),
#                ('and', 148),
#                ('a', 118)],
#  'Fusion': [('the', 16), ('i', 13), ("'s", 11), ('to', 10), ('in', 9)],
#  'Gangsta Rap': [('i', 34), ('the', 26), ('and', 19), ('a', 13), ('my', 12)],
#  'Glam Rock': [('the', 39),
#                ('bennie', 38),
#                ('and', 36),
#                ('i', 16),
#                ('la-la-la-la-laa', 15)],
#  'Gospel': [('you', 32), ('i', 27), ('a', 24), ('to', 23), ('the', 23)],
#  'Grunge': [('i', 221), ('you', 144), ('and', 84), ("'m", 82), ('a', 71)],
#  'Hard Rock': [('the', 45), ('you', 34), ('it', 29), ('to', 28), ('i', 27)],
#  'Hardcore Rap': [('i', 132),
#                   ('you', 117),
#                   ('the', 48),
#                   ('on', 46),
#                   ("'em", 35)],
#  'Heavy Metal': [('i', 34), ('the', 30), ('to', 28), ('you', 27), ('just', 16)],
#  'Hip Hop/Rap': [('i', 1005),
#                  ('the', 629),
#                  ('you', 625),
#                  ('a', 461),
#                  ('to', 358)],
#  'Holiday': [('the', 249),
#              ('and', 162),
#              ('a', 145),
#              ('christmas', 126),
#              ("'s", 95)],
#  'Honky Tonk': [('to', 28),
#                 ('when', 25),
#                 ('the', 18),
#                 ('you', 18),
#                 ('and', 16)],
#  'House': [('i', 104), ('you', 100), ('oh', 58), ('your', 52), ('the', 45)],
#  'Indie Pop': [('i', 22),
#                ('you', 14),
#                ("'m", 11),
#                ('say', 8),
#                ('something', 8)],
#  'Indie Rock': [('i', 121), ('you', 86), ('love', 51), ('the', 42), ('my', 41)],
#  'Industrial': [('the', 41),
#                 ('through', 19),
#                 ('i', 16),
#                 ('and', 11),
#                 ('burn', 11)],
#  'J-Pop': [('you', 28), ('a', 25), ('me', 22), ('努力', 21), ('未来', 21)],
#  'Jazz': [('i', 42), ('you', 33), ('the', 24), ('and', 22), ('a', 21)],
#  'K-Pop': [('i', 19), ('you', 18), ('huh', 13), ('it', 13), ("'em", 12)],
#  'Latin': [('que', 150), ('no', 141), ('me', 128), ('y', 98), ('te', 87)],
#  'Latin Rap': [('que', 25), ('le', 17), ('la', 15), ('pa', 14), ('los', 12)],
#  'Latin Urban': [('morena', 24),
#                  ('dale', 21),
#                  ('moreno', 20),
#                  ('y', 17),
#                  ('con', 16)],
#  'New Age': [('your', 11), ('who', 10), ('can', 8), ('say', 8), ('only', 8)],
#  'New Wave': [('i', 79), ('the', 67), ("'s", 58), ('it', 54), ("n't", 53)],
#  'Oldies': [('i', 24), ('and', 17), ('a', 15), ('it', 9), ('that', 7)],
#  'Pop': [('i', 2697), ('you', 2302), ('the', 1401), ('and', 1005), ('it', 931)],
#  'Pop/Rock': [('i', 348),
#               ('you', 333),
#               ('the', 226),
#               ('and', 166),
#               ('it', 142)],
#  'Praise & Worship': [('and', 22),
#                       ('i', 19),
#                       ('the', 16),
#                       ('how', 14),
#                       ('is', 14)],
#  'Psychedelic': [('the', 23), ('i', 20), ('and', 16), ('she', 15), ('you', 15)],
#  'Punk': [('i', 52), ('the', 43), ('na-na', 36), ('to', 30), ('you', 29)],
#  'R&B/Soul': [('i', 254), ('you', 234), ('it', 175), ('the', 107), ('me', 104)],
#  'Rap': [('the', 73), ('i', 62), ('you', 55), ('a', 51), ('and', 49)],
#  'Reggae': [('it', 25),
#             ('stir', 23),
#             ('up', 21),
#             ('darling', 12),
#             ('little', 11)],
#  'Regional Mexicano': [('en', 8), ('el', 6), ('la', 6), ('lo', 6), ('y', 4)],
#  'Rock': [('i', 943), ('you', 784), ('the', 659), ('and', 500), ('a', 452)],
#  'Roots Rock': [('the', 33),
#                 ('bring', 20),
#                 ('back', 20),
#                 ('memories', 20),
#                 ('to', 14)],
#  'Salsa y Tropical': [('y', 29),
#                       ('que', 25),
#                       ('no', 23),
#                       ('me', 13),
#                       ('el', 13)],
#  'Singer/Songwriter': [('the', 65),
#                        ('i', 55),
#                        ('of', 34),
#                        ('you', 32),
#                        ('in', 27)],
#  'Ska': [('life', 16), ('goes', 16), ('on', 16), ('the', 15), ('a', 13)],
#  'Soft Rock': [('i', 58), ('why', 53), ('the', 45), ('and', 41), ('me', 26)],
#  'Soul': [('you', 118), ('i', 109), ('the', 71), ('me', 57), ('it', 48)],
#  'Soundtrack': [('and', 202),
#                 ('the', 192),
#                 ('i', 178),
#                 ('you', 106),
#                 ('to', 94)],
#  'Teen Pop': [('you', 44), ('i', 42), ('me', 29), ('but', 26), ('so', 24)],
#  'Traditional Country': [('i', 163),
#                          ('the', 151),
#                          ('you', 131),
#                          ('and', 110),
#                          ('a', 85)],
#  'Unclassified': [('i', 759),
#                   ('the', 490),
#                   ('you', 446),
#                   ('to', 312),
#                   ('and', 286)],
#  'Vocal': [('the', 14), ("n't", 8), ('a', 8), ('i', 7), ('like', 7)]}

# %% [markdown]
# ### Remove Stop Words

# %% [markdown]
# The above output does contain common stop words like a, the, an that may not be what the consumer of this dataset desired. In the next section we can filter the  data dictionary to remoove these stop words found in /data/stop-words.txt

# %%
stop_words = [word.strip() for word in open("data/stop-words.txt", "r").readlines()]
sorted_count_by_genre_stop = {}

def filter_stop_words(genre_word_count, stop_words):
    
    genre_stop_word_count = {}
    
    for genre in genre_word_count.keys():
        word_list = [count_pair for count_pair in genre_word_count[genre] if count_pair[0] not in stop_words]
        genre_stop_word_count[genre] = word_list
        
    return genre_stop_word_count


sorted_count_by_genre_stop = filter_stop_words(sorted_count_by_genre,stop_words)
pp.pprint({genre: word_tuples[:5] for genre, word_tuples in sorted_count_by_genre_stop.items()})
# Out:
# {'Adult Alternative': [('love', 22),
#                        ('another', 20),
#                        ('tears', 12),
#                        ('used', 12),
#                        ('wan', 10)],
#  'Adult Contemporary': [('na', 45),
#                         ('never', 44),
#                         ('gon', 43),
#                         ('someone', 34),
#                         ('saved', 30)],
#  'Alternative': [('know', 90),
#                  ('oh', 77),
#                  ('like', 57),
#                  ('never', 43),
#                  ('tell', 41)],
#  'Alternative Folk': [('na', 15),
#                       ('got', 8),
#                       ('gon', 8),
#                       ('wan', 7),
#                       ('dark', 6)],
#  'Alternative Rap': [('like', 28),
#                      ('hey', 27),
#                      ('ya', 27),
#                      ('right', 19),
#                      ('baby', 15)],
#  'Ambient': [('like', 24), ('could', 6), ('lie', 6), ('say', 6), ('let', 5)],
#  'American Trad Rock': [('tired', 7),
#                         ('town', 5),
#                         ('last', 4),
#                         ('oh', 4),
#                         ('grew', 3)],
#  'Americana': [('’', 13), ('god', 10), ('speed', 6), ('wan', 5), ('na', 5)],
#  'Arena Rock': [('great', 3),
#                 ('better', 2),
#                 ('dogs', 2),
#                 ('things', 2),
#                 ('seem', 2)],
#  'Blues': [('know', 30), ('oh', 16), ('yeah', 9), ('ai', 8), ('gone', 8)],
#  'Blues-Rock': [('ai', 24),
#                 ('son', 6),
#                 ('lord', 5),
#                 ('fortunate', 5),
#                 ('one', 5)],
#  'Bollywood': [('tum', 11), ('ho', 10), ('dil', 8), ('ke', 8), ('pal-pal', 7)],
#  'British Invasion': [('hoo', 28),
#                       ('yeah', 14),
#                       ('ooo', 14),
#                       ('name', 12),
#                       ('ah', 8)],
#  'Britpop': [('winner', 6), ('takes', 5), ('feel', 3), ('wan', 2), ('na', 2)],
#  'CCM': [('say', 18),
#          ('pray', 15),
#          ('name', 14),
#          ('believe', 14),
#          ('jesus', 12)],
#  'Christian & Gospel': [('every', 113),
#                         ('praise', 94),
#                         ('thank', 89),
#                         ('jesus', 68),
#                         ('god', 60)],
#  'Christian Pop': [('god', 23),
#                    ('imagine', 21),
#                    ('wo', 16),
#                    ('child', 15),
#                    ('love', 14)],
#  'Christmas': [('christmas', 40),
#                ('night', 29),
#                ('wo', 18),
#                ('want', 17),
#                ('need', 13)],
#  'Christmas: Modern': [('reindeer', 12),
#                        ('rudolph', 8),
#                        ('red-nosed', 4),
#                        ('nose', 4),
#                        ('say', 4)],
#  'Classic Christian': [('oh', 49),
#                        ('rejoice', 44),
#                        ('conqueror', 13),
#                        ('victorious', 11),
#                        ('come', 7)],
#  'Classical Crossover': [('love', 5),
#                          ('darling', 5),
#                          ('found', 4),
#                          ('perfect', 4),
#                          ('baby', 3)],
#  'College Rock': [('everybody', 6),
#                   ('wants', 6),
#                   ('rule', 6),
#                   ('world', 5),
#                   ('never', 4)],
#  'Comedy': [('turkey', 23), ('eat', 9), ('love', 7), ('got', 7), ('``', 6)],
#  'Contemporary Country': [('time', 29),
#                           ('hope', 28),
#                           ('know', 23),
#                           ('na', 20),
#                           ('yeah', 20)],
#  'Contemporary Folk': [('yeah', 9),
#                        ('like', 8),
#                        ('count', 8),
#                        ('silence', 6),
#                        ('2', 6)],
#  'Contemporary R&B': [('baby', 54),
#                       ('annie', 48),
#                       ('okay', 48),
#                       ('ai', 45),
#                       ('never', 37)],
#  'Country': [('love', 103),
#              ('know', 89),
#              ('got', 73),
#              ('like', 68),
#              ('one', 66)],
#  'Dance': [('good', 14),
#            ('yeah', 13),
#            ('nigga', 10),
#            ('know', 10),
#            ('feelin', 10)],
#  'Dirty South': [('different', 37),
#                  ('yeah', 22),
#                  ('save', 20),
#                  ('wan', 20),
#                  ('na', 20)],
#  'Disco': [('ma-ma-say', 29),
#            ('ma-ma-sah', 29),
#            ('ma-ma-coo-sah', 29),
#            ('stayin', 26),
#            ('alive', 26)],
#  'Doo Wop': [('’', 12), ('love', 11), ('get', 9), ('got', 8), ('like', 7)],
#  'East Coast Rap': [('god', 7),
#                     ('way', 7),
#                     ('jesus', 6),
#                     ('tryna', 5),
#                     ('walk', 4)],
#  'Electronic': [('love', 83),
#                 ('got', 71),
#                 ('want', 71),
#                 ('like', 64),
#                 ('oh', 57)],
#  'Electronica': [('crazy', 9),
#                  ('think', 6),
#                  ('remember', 4),
#                  ('make', 3),
#                  ('ha', 3)],
#  'Farsi': [('که', 9), ('زن،', 6), ('زندگی،', 6), ('آزادی', 6), ('به', 5)],
#  'Folk': [('blackbird', 7),
#           ('fly', 6),
#           ('night', 5),
#           ('waiting', 5),
#           ('moment', 5)],
#  'Folk-Rock': [('hallelujah', 39),
#                ('love', 34),
#                ('know', 32),
#                ('baby', 28),
#                ('go', 26)],
#  'Fusion': [('bless', 7), ('rains', 7), ('africa', 7), ('gon', 6), ('na', 6)],
#  'Gangsta Rap': [('got', 6), ('said', 6), ('``', 6), ("''", 6), ('warren', 5)],
#  'Glam Rock': [('bennie', 38),
#                ('la-la-la-la-laa', 15),
#                ('jets', 14),
#                ('oh', 13),
#                ('crocodile', 12)],
#  'Gospel': [('make', 17), ('change', 15), ('hoo', 13), ('got', 12), ('na', 11)],
#  'Grunge': [('hello', 37),
#             ('yet', 34),
#             ('still', 26),
#             ('one', 22),
#             ('know', 14)],
#  'Hard Rock': [('way', 18),
#                ('time', 16),
#                ('love', 16),
#                ('never', 15),
#                ('always', 15)],
#  'Hardcore Rap': [("'em", 35),
#                   ('shitted', 24),
#                   ('still', 23),
#                   ('think', 21),
#                   ('know', 14)],
#  'Heavy Metal': [('want', 14),
#                  ('trust', 10),
#                  ('father', 10),
#                  ('wanted', 8),
#                  ('leave', 7)],
#  'Hip Hop/Rap': [('like', 141),
#                  ('get', 130),
#                  ('know', 124),
#                  ('got', 116),
#                  ('fuck', 109)],
#  'Holiday': [('christmas', 126),
#              ('merry', 58),
#              ('love', 42),
#              ('snow', 30),
#              ('hallelujah', 29)],
#  'Honky Tonk': [('know', 16), ("'em", 8), ('got', 6), ('away', 5), ('hold', 4)],
#  'House': [('oh', 58), ('come', 37), ('mean', 28), ('love', 27), ('put', 24)],
#  'Indie Pop': [('say', 8),
#                ('something', 8),
#                ('giving', 7),
#                ('anywhere', 3),
#                ('would', 3)],
#  'Indie Rock': [('love', 51),
#                 ('go', 26),
#                 ('’', 20),
#                 ('please', 19),
#                 ('woah', 16)],
#  'Industrial': [('burn', 11),
#                 ('dig', 10),
#                 ('back', 10),
#                 ('ditches', 9),
#                 ('witches', 9)],
#  'J-Pop': [('努力', 21), ('未来', 21), ('beautiful', 21), ('star', 21), ('oh', 15)],
#  'Jazz': [('cock', 11), ('got', 10), ('oh', 9), ('baby', 9), ('cry', 7)],
#  'K-Pop': [('huh', 13), ("'em", 12), ('mic', 9), ('drop', 9), ('난', 9)],
#  'Latin': [('que', 150), ('te', 87), ('la', 85), ('tú', 81), ('yo', 77)],
#  'Latin Rap': [('que', 25), ('le', 17), ('la', 15), ('pa', 14), ('los', 12)],
#  'Latin Urban': [('morena', 24),
#                  ('dale', 21),
#                  ('moreno', 20),
#                  ('con', 16),
#                  ('baila', 16)],
#  'New Age': [('say', 8), ('time', 8), ('heart', 7), ('love', 5), ('day', 3)],
#  'New Wave': [('go', 26), ('let', 24), ('na', 20), ('love', 19), ('start', 17)],
#  'Oldies': [('life', 5), ('back', 4), ('get', 4), ('know', 3), ('gon', 3)],
#  'Pop': [('like', 365),
#          ('know', 314),
#          ('na', 303),
#          ('got', 275),
#          ('yeah', 260)],
#  'Pop/Rock': [('got', 75), ('oh', 59), ('know', 49), ('na', 44), ('love', 41)],
#  'Praise & Worship': [('great', 13),
#                       ('hallelujah', 12),
#                       ('god', 10),
#                       ('praise', 10),
#                       ('got', 6)],
#  'Psychedelic': [('raspberry', 9),
#                  ('beret', 9),
#                  ('kind', 5),
#                  ('one', 4),
#                  ('would', 4)],
#  'Punk': [('na-na', 36), ('na', 18), ('one', 14), ('take', 13), ('sun', 12)],
#  'R&B/Soul': [('oh', 49),
#               ('beat', 48),
#               ('need', 47),
#               ('yeah', 42),
#               ('come', 33)],
#  'Rap': [('ice', 43),
#          ('crossroads', 37),
#          ('baby', 21),
#          ('like', 18),
#          ('na', 18)],
#  'Reggae': [('stir', 23),
#             ('darling', 12),
#             ('little', 11),
#             ('come', 9),
#             ('baby', 3)],
#  'Regional Mexicano': [('en', 8), ('el', 6), ('la', 6), ('lo', 6), ('..', 4)],
#  'Rock': [('love', 190),
#           ('oh', 137),
#           ('la', 123),
#           ('yeah', 119),
#           ('come', 109)],
#  'Roots Rock': [('bring', 20),
#                 ('back', 20),
#                 ('memories', 20),
#                 ('doo-doo-doo-doo', 12),
#                 ('yeah', 10)],
#  'Salsa y Tropical': [('que', 25),
#                       ('el', 13),
#                       ('yo', 12),
#                       ('te', 9),
#                       ('amor', 9)],
#  'Singer/Songwriter': [('never', 14),
#                        ('mine', 13),
#                        ('dandelions', 10),
#                        ('wishin', 10),
#                        ('fall', 9)],
#  'Ska': [('life', 16),
#          ('goes', 16),
#          ('molly', 8),
#          ('ob-la-di', 8),
#          ('ob-la-da', 8)],
#  'Soft Rock': [('night', 24),
#                ('moves', 23),
#                ('way', 17),
#                ('love', 13),
#                ('say', 13)],
#  'Soul': [('like', 25), ('stand', 24), ('oh', 19), ('baby', 18), ('never', 17)],
#  'Soundtrack': [('``', 33), ('na', 32), ("''", 31), ('said', 29), ('make', 25)],
#  'Teen Pop': [('way', 14),
#               ('call', 13),
#               ('tell', 12),
#               ('maybe', 12),
#               ('number', 11)],
#  'Traditional Country': [('time', 56),
#                          ('good', 32),
#                          ('always', 28),
#                          ('love', 28),
#                          ('jingle', 28)],
#  'Unclassified': [('like', 101),
#                   ('love', 89),
#                   ('get', 83),
#                   ('dey', 77),
#                   ('na', 67)],
#  'Vocal': [('like', 7), ('ai', 7), ('head', 6), ('said', 5), ('kick', 5)]}

# %% [markdown]
# ### OutPut Dataset

# %%
import json

json_object = json.dumps(sorted_count_by_genre, indent=4)
 
# Writing to data/word_count_by_genre.json
with open("data/word_count_by_genre.json", "w") as outfile:
    outfile.write(json_object)

# %%
# Store the lyric data set so we don't have to scrape again to run processing
# NOTE: This file is not including with data set but it can be recreated using the above code
json_object_2 = json.dumps(songs_with_metadata, indent=4)
with open("data/tracks_with_lyrics.json", "w") as outfile:
    outfile.write(json_object_2)
